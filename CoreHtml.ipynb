# %% [markdown]
# #Core-Html

# %%
# 1. Build a simple webpage that displays text as shown in the below image.
"""
 <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
<div style="border: 2px solid black;">
    <h3>This text will be bolded.</h3>
    <em>This text will be italic.</em>
    <br>
    <br>
    <u>This text will be underlined</u>
    <br>
    <br>
    <span style="background-color: yellow;">This text will be highlighted</span>
    <p>This is normal text <sup>This will be super scripted</sup> This is normal again</p>
     <p>This is normal text <sub>This text will be subscripted</sub></p>
     Normal Text <small>Small Text</small>
     <br>
     <del>This text will be deleted</del>
</div>
</body>
</html>
"""

#2. Build a simple webpage that helps users navigate different web development-related websites. Note: On clicking the hyperlink the web pages should open in a new tab. Below is a reference image.
"""
 <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>

<div style="border: 2px solid black;">
     <h1>Navigate Me:</h1>
     <p>Take me to <a href="#">PW Skills</a> to buy a course.</p>
     <p>Take me to <a href="#">MDN docs</a> to know more about Web Development.</p>
     <p>Take me to <a href="#">PW Skills Lab</a> to pratice live coding.</p>
    </div>
</body>
</html>

"""

# 3 Build a simple blog web page with 3 pages home, web development, and web design. Each page must contain hyperlinks to other pages in the top, a heading of the page topic and a paragraph of information.For the home page you can add some information about yourself.
"""
<!DOCTYPE html>
<html lang="en">
  <head>
    <meta charset="UTF-8" />
    <meta name="viewport" content="width=device-width, initial-scale=1.0" />
    <title>Document</title>
  </head>
  <body>
    <div>
      <h1>Himanshu Rajput</h1>
      <p>
        <a href="#Home" target="_blank">Home</a>
        <a href="#webDevelopment">Web-Development</a>
        <a href="#webDesign">Web-Design</a>
      </p>
      <p>I am create a simple Web Page with some dummy data. .</p>
    </div>

    <br />
    <br />

    <div id="Home">
      <h1>Home Page</h1>
      <br />

      Lorem ipsum dolor, sit amet consectetur adipisicing elit. Pariatur id vel
      ratione! Odit illum laborum eos eveniet recusandae ipsum suscipit aperiam?
      Amet alias, doloremque nihil atque necessitatibus assumenda similique
      dolorem.
    </div>
    <br />
    <br />
    <div id="webDevelopment">
      <h1>Web-Development</h1>
      <p>
        Lorem ipsum dolor sit amet consectetur, adipisicing elit. Sint eius
        necessitatibus quod praesentium blanditiis tenetur adipisci vero, aut
        expedita nostrum sequi numquam enim labore, harum eos fugiat beatae
        nulla molestiae qui hic atque modi distinctio! Necessitatibus ea dolorem
        voluptatum dolor, illo suscipit in magni expedita aliquam sapiente, hic
        eum et quae reiciendis id. Voluptatum dolor unde modi magnam mollitia
        corporis voluptatibus, perspiciatis in praesentium beatae nemo cum, eius
        aliquam, ipsa quo distinctio? Pariatur facere labore ipsa ad eaque
        possimus perferendis tempora. Nesciunt iure, obcaecati dolorem iusto
        inventore minima laboriosam ipsum facilis similique nihil impedit
        debitis laborum tempore perferendis distinctio veniam?
      </p>
    </div>
    <br />
    <br />
    <div id="webDesign">
      <h1>Web-Design</h1>
      <p>
        Lorem ipsum dolor sit amet consectetur, adipisicing elit. Sint eius
        necessitatibus quod praesentium blanditiis tenetur adipisci vero, aut
        expedita nostrum sequi numquam enim labore, harum eos fugiat beatae
        nulla molestiae qui hic atque modi distinctio! Necessitatibus ea dolorem
        voluptatum dolor, illo suscipit in magni expedita aliquam sapiente, hic
        eum et quae reiciendis id. Voluptatum dolor unde modi magnam mollitia
        corporis voluptatibus, perspiciatis in praesentium beatae nemo cum, eius
        aliquam, ipsa quo distinctio? Pariatur facere labore ipsa ad eaque
        possimus perferendis tempora. Nesciunt iure, obcaecati dolorem iusto
        inventore minima laboriosam ipsum facilis similique nihil impedit
        debitis laborum tempore perferendis distinctio veniam?
      </p>
    </div>
  </body>
</html>

"""

#4. Create an ordered list of HTML tags. Each list item must include the tag name and some information about the tag.
"""
<!DOCTYPE html>
<html lang="en">
  <head>
    <meta charset="UTF-8" />
    <meta name="viewport" content="width=device-width, initial-scale=1.0" />
    <title>Document</title>
  </head>
  <body>
    <h1>PW SKILLS</h1>
    <h2>Courses</h2>
    <ol>The main type of lists in HTML are:
        <li><b>ul:</b> It stands for an unordered list, which means every list item will have a bullet point in front of it. </li>
        <li><b>ol:</b> It stands for an ordered list. </li>
        <li><b>dl:</b> It stands for an Definition List.</li>

    </ol>
</body>
</html>

"""

#5.Create a description list of full stack web development tech stack, using the <dl> tag. Each term should be a tech stack name and each description should be a brief explanation of what the tech stack is used for.
"""
<!DOCTYPE html>
<html lang="en">
  <head>
    <meta charset="UTF-8" />
    <meta name="viewport" content="width=device-width, initial-scale=1.0" />
    <title>Document</title>
  </head>
  <body>
    <h1>Full Stack Web Development</h1>
    <dl>
        <dt>HTML (Hypertext Markup Language) : </dt>
        <dd>- Html allows you to structure web pages and the content on them.</dd>
        <dt>CSS (Cascading Style Sheets) : </dt>
        <dd>- Cascading Style Sheets, fondly referred to as CSS, is a simply designed language intended to simplify the process of making web pages presentable.</dd>
        <dt>JAVASCRIPT :</dt>
        <dd>- JavaScript is a famous scripting language used to create the magic on the sites to make the site interactive for the user.</dd>
        <dt>REACT JS :</dt>
         <dd>React is a declarative,efficient, and flexible JavaScript library for building user interfaces.ReactJs is an open-source, component-based frontend library responsible only for the view layer of the application.it is maintained by Facebook.</dd>
         <dt>Node.Js :</dt>
         <dd>Node.js is an open source and cross-platform runtime environment for executing JavaScript code outside of a browser. You need to remember that NodeJS is not a framework and it’s not a programming language. Most of the people are confused and understand it’s a framework or a programming language. We often use Node.js for building back-end services like APIs like Web App or Mobile App. It’s used in production by large companies such as Paypal, Uber, Netflix, Walmart and so on.</dd>
         <dt>MongoDB:</dt>
         <dd>MongoDB, the most popular NoSQL database, is an open source document-oriented database. The term ‘NoSQL’ means ‘non-relational’. It means that MongoDB isn’t based on the table-like relational database structure but provides an altogether different mechanism for storage and retrieval of data.</dd>
         <dt>SQL :</dt>
         <dd>Structured Query Language is a standard Database language which is used to create, maintain and retrieve the relational database.
        </dd>
    </dl>
</body>
</html>
"""

#6. Create an ordered list of the full stack web development tech stack HTML, CSS, and JS. For each tech stack, create a table that lists the tech stack name, its primary use cases, and some key features or benefits. Below is a reference image.
"""
 <!DOCTYPE html>
<html lang="en">
  <head>
    <meta charset="UTF-8" />
    <meta name="viewport" content="width=device-width, initial-scale=1.0" />
    <title>Document</title>
  </head>
  <body>
    <ol>
        <li>HTML</li>
        <br>
        <table border="1">
            <tr>
                <th>Primary Use Cases</th>
                <th>Key Features/Benefits</th>
            </tr>
            <tr>
                <td>Building the structure of web pages</td>
                <td>
                    <ol>
                        <li type="circle" > Simple and easy to learn</li>
                        <li type="circle" > compatibale with all web browsers</li>
                        <li type="circle" > Allows for semantic markup</li>

                    </ol>
                </td>

            </tr>
        </table>
    </ol>

    <ol>
        <li>CSS</li>
        <br>
        <table border="1">
            <tr>
                <th>Primary Use Cases</th>
                <th>Key Features/Benefits</th>
            </tr>
            <tr>
                <td>Styling and layout of web pages</td>
                <td>
                    <ol>
                        <li type="circle" > Allows for separationof content and presentation</li>
                        <li type="circle" > Enables responsive design</li>
                        <li type="circle" > Offers a wide range of styling options</li>

                    </ol>
                </td>

            </tr>
        </table>
    </ol>

    <ol>
        <li>JAVASCRIPT</li>
        <br>
        <table border="1">
            <tr>
                <th>Primary Use Cases</th>
                <th>Key Features/Benefits</th>
            </tr>
            <tr>
                <td>Allows developers to maipulated the web pages</td>
                <td>
                    <ol>
                        <li type="circle" > Functions in JS are objects.</li>
                        <li type="circle" > It can handle date and time.</li>
                        <li type="circle" > Performs Form Validation.</li>

                    </ol>
                </td>

            </tr>
        </table>
    </ol>
</body>
</html>

"""

#7.Build a complex nested list structure representing a multi-level table of contents. Use unordered lists (<ul>) and list items (<li>) with inline-block styling to create a structured layout. Apply formatting tags to enhance the presentation of list items.
"""
<!DOCTYPE html>
<html lang="en">
  <head>
    <meta charset="UTF-8" />
    <meta name="viewport" content="width=device-width, initial-scale=1.0" />
    <title>Document</title>
  </head>
  <body>
   <ul>
    <li> <u>Part 1: Introduction</u></li>
    <li><u>Part 2: Getting Started</u>
        <ul>
            <li><u>2.1 Installing the Software</u></li>
            <li><u>2.2 Creating a New Project</u>
                <ul>
                    <li><u>2.2.1 Project Templates</u></li>
                    <li><u>2.2.2 customizing Settings</u></li>
                </ul>
            </li>
            <li><u>2.3 Exloring the Interface</u>
                <ul>
                    <li><u>2.3.1 Toolbar Features</u></li>
                    <li><u>2.3.2 Panel Layout</u></li>
                    <ul>
                        <li><u>2.3.2.1 Docking Panels</u></li>
                        <li><u>2.3.2.2 Tabbed Interface</u></li>
                    </ul>
                </ul>
            </li>
        </ul>
    </li>
    <li><u>Part 3. Advanced Topics</u>
        <ul>
            <li><u>3.1 Working with Plugins</u></li>
            <ul>
                <li><u>3.1.1 Installing Plugins</u></li>
                <li><u>3.1.2 Plugin Configuration</u></li>
            </ul>
            <li><u>3.2 customizing the UI</u></li>
            <ul>
                <li><u>3.2.1 Changing Themes</u></li>
                <li><u>3.2.2 Configuring Shortcuts</u></li>
            </ul>
            <li><u>3.3 Optimising Performance</u></li>
            <ul>
                <li><u>3.3.1 Caching Strategies</u></li>
                <li><u>3.1.2 Resources Minification</u></li>
            </ul>
        </ul>
    </li>
    <li><u>Part 4: Conclusion</u></li>
   </ul>
</body>
</html>
"""

#8. Create a table to display a conference schedule. Each row corresponds to a time slot, and each column corresponds to a room. Some time slots might have multiple sessions running simultaneously in different rooms. Utilize rowspan and colspan attributes as necessary to accommodate this complex schedule. (use table attribute “cellpadding”  to give extra padding in each table cell ).
"""
 <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>

    <h1>Conference Schedule</h1>

    <table border="1" cellpadding="5" cellspacing="5" >
        <tr>
            <th>Time</th>
            <th>Room 1</th>
            <th>Room 2</th>
            <th> Room 3</th>
            <th>Room 4</th>
        </tr>
        <tr>
            <td rowspan="3">9:00 AM - 10:00 AM</td>
            <td rowspan="2">Keynote</td>
            <td>Session A</td>
            <td>Session B</td>
            <td rowspan="3">Session C</td>
        </tr>
        <tr>
            <td>Session D</td>
            <td>Session E</td>
        </tr>
        <tr>
            <td>10:30 AM - 11:30 AM</td>
            <td colspan="2">Session F</td>

        </tr>
        <tr>
            <td >12:00 PM - 1:00 PM</td>
            <td colspan="4">Lunch Break</td>

        </tr>
        <tr>
            <td rowspan="2">1:00 PM - 2:00 PM</td>
            <td>Session G</td>
            <td rowspan="2">Session H</td>
            <td>Session I</td>
            <td>Session J</td>

        </tr>
        <tr>
            <td>Session K</td>
            <td>Session L</td>
            <td>Session M</td>

        </tr>

    </table>

</body>
</html>

"""
